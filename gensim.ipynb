# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
from gensim import corpora
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Using TensorFlow backend.
# 2017-07-17 09:48:14,666 : INFO : 'pattern' package not found; tag filters are not available for English

# %%
# import csv
# with open('C:/Users/Yanbo/Documents/Code/Data/shenjianshou/jd_logi_reviews.csv', encoding='utf-8') as csvfile:
#     reader = csv.DictReader(csvfile)
#     reviews = []
#     for row in reader:
#         reviews.append(row['评价内容(content)'])

# %%
import pandas as pd
df = pd.read_csv('C:/Users/Yanbo/Documents/Code/Data/shenjianshou/jd_logi_reviews.csv', encoding='utf-8',index_col = '商品ID(product_id)')

# %%
reviews = df.loc[3903182]['评价内容(content)'][0:10]
print (reviews)
# Out:
# 商品ID(product_id)
# 3903182    到货快。键盘大小适中，份量适中，链接容易。手感很好，就是14寸笔电的尺寸和手感，手感甚至更好...
# 3903182                         好，比其它品牌的真的好多了，连接信号好，输入连贯，不卡。
# 3903182                                     很不错！！！！罗技产品值得信赖！
# 3903182                                       很轻便，质感很好，携带方便。
# 3903182                                      按键的感觉很喜欢，造型也不错。
# 3903182    买来配MAC AIR的，感觉比air自带键盘稍小，确切的说是键距稍微小一点，长篇打字应该会有...
# 3903182                   原来考虑到圆形的按键会不会有问题，事实证明没有，现在把它当生产工具用
# 3903182                                           很好的键盘 特别好用
# 3903182       上午下单，下午就送到了。一个字&ldquo;快&rdquo;考虑安卓PC,Mac就选择这款。
# 3903182                                         不错，手感不错！！！！！
# Name: 评价内容(content), dtype: object

# %%
stop_words = []
with open('stoplist.txt','r',encoding='utf-8') as st:
    for i in st.readlines():
        i = i.rstrip()
        stop_words.append(i)

# %%
import jieba.posseg as pseg
attri_reviews = []
for i in reviews:
    words = pseg.cut(i)
    for word, flag in words:
        print('%s %s' % (word, flag))
        attri_reviews.append()
# Out:
# Building prefix dict from the default dictionary ...
# 2017-07-17 09:48:32,886 : DEBUG : Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\Yanbo\AppData\Local\Temp\jieba.cache
# 2017-07-17 09:48:32,894 : DEBUG : Loading model from cache C:\Users\Yanbo\AppData\Local\Temp\jieba.cache
# Loading model cost 1.057 seconds.
# 2017-07-17 09:48:33,946 : DEBUG : Loading model cost 1.057 seconds.
# Prefix dict has been built succesfully.
# 2017-07-17 09:48:33,949 : DEBUG : Prefix dict has been built succesfully.
# 到货 v
# 快 a
# 。 x
# 键盘 n
# 大小 b
# 适中 v
# ， x
# 份量 n
# 适中 v
# ， x
# 链接 n
# 容易 a
# 。 x
# 手感 n
# 很 d
# 好 a
# ， x
# 就是 d
# 14 m
# 寸笔电 l
# 的 uj
# 尺寸 n
# 和 c
# 手感 n
# ， x
# 手感 n
# 甚至 d
# 更好 d
# （ x
# 对比 v
# 我 r
# 的 uj
# ThinkPad eng
# 和 c
# 我 r
# 女朋友 n
# 的 uj
# 华硕 nr
# 超 v
# 极本 a
# ） x
# 。 x
# 我 r
# 用来 v
# 配 v
# Mac eng
#   x
# mini eng
#   x
# 的 uj
# ， x
# 看中 v
# 其 r
# 匹配 v
# Mac eng
#   x
# 的 uj
# 按键 n
# 设置 vn
# 。 x
# 好 a
# ， x
# 比 p
# 其它 r
# 品牌 n
# 的 uj
# 真的 d
# 好多 m
# 了 ul
# ， x
# 连接 v
# 信号 n
# 好 a
# ， x
# 输入 v
# 连贯 nr
# ， x
# 不卡 n
# 。 x
# 很 zg
# 不错 a
# ！ x
# ！ x
# ！ x
# ！ x
# 罗技 nz
# 产品 n
# 值得 v
# 信赖 n
# ！ x
# 很 zg
# 轻便 a
# ， x
# 质感 n
# 很 d
# 好 a
# ， x
# 携带方便 l
# 。 x
# 按键 n
# 的 uj
# 感觉 n
# 很 zg
# 喜欢 v
# ， x
# 造型 n
# 也 d
# 不错 a
# 。 x
# 买来 v
# 配 v
# MAC eng
#   x
# AIR eng
# 的 uj
# ， x
# 感觉 n
# 比 p
# air eng
# 自带 n
# 键盘 n
# 稍 d
# 小 a
# ， x
# 确切的说 l
# 是 v
# 键 n
# 距 p
# 稍微 d
# 小 a
# 一点 m
# ， x
# 长篇 b
# 打字 v
# 应该 v
# 会 v
# 有点累 v
# ， x
# 需要 v
# 适应 v
# 一下 m
# 。 x
# 3 x
# 切换 v
# 功能 n
# 挺强 v
# ， x
# MAC eng
#   x
# air eng
# / x
# IPHONE6 eng
# / x
# IPAD eng
#   x
# mini eng
#   x
# 这个 r
# 3 m
# 个 m
# 适配 v
# 都 d
# 没 v
# 问题 n
# ， x
# 没试 v
# windows eng
# ， x
# 估计 v
# 应该 v
# 没 v
# 问题 n
# 。 x
# 整套 b
# 很棒 a
# ， x
# 要是 c
# 能 v
# 再 d
# 大 a
# 一点点 m
# 就 d
# 完美 a
# 了 ul
# 原来 d
# 考虑 v
# 到 v
# 圆形 n
# 的 uj
# 按键 n
# 会 v
# 不会 v
# 有 v
# 问题 n
# ， x
# 事实证明 l
# 没有 v
# ， x
# 现在 t
# 把 p
# 它 r
# 当 p
# 生产工具 l
# 用 p
# 很好 a
# 的 uj
# 键盘 n
#   x
# 特别 d
# 好 a
# 用 p
# 上午 t
# 下单 n
# ， x
# 下午 t
# 就 d
# 送到 v
# 了 ul
# 。 x
# 一个 m
# 字 n
# & x
# ldquo eng
# ; x
# 快 a
# & x
# rdquo eng
# ; x
# 考虑 v
# 安卓 nr
# PC eng
# , x
# Mac eng
# 就 d
# 选择 v
# 这 r
# 款 m
# 。 x
# 不错 a
# ， x
# 手感 n
# 不错 a
# ！ x
# ！ x
# ！ x
# ！ x
# ！ x

# %%
import jieba
import jieba.analyse


new_reviews = []
for i in reviews:
    data = jieba.cut(i,cut_all=False)
    try:
        texts = [word for word in data if word not in stop_words]
    except AttributeError:
        pass
#     print (texts)
#     temp_text = " ".join(texts)
#     print (temp_text)
    new_reviews.append(texts)

# with open("jd_reviews_cut.txt", "w", encoding='utf-8') as f: 
#     f.write(str(new_reviews))
# Out:
# Building prefix dict from the default dictionary ...
# 2017-07-16 16:25:14,786 : DEBUG : Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\Yanbo\AppData\Local\Temp\jieba.cache
# 2017-07-16 16:25:14,792 : DEBUG : Loading model from cache C:\Users\Yanbo\AppData\Local\Temp\jieba.cache
# Loading model cost 1.017 seconds.
# 2017-07-16 16:25:15,807 : DEBUG : Loading model cost 1.017 seconds.
# Prefix dict has been built succesfully.
# 2017-07-16 16:25:15,810 : DEBUG : Prefix dict has been built succesfully.

# %%
# dictionary = corpora.Dictionary(new_reviews)
# dictionary.save('jd_reviews_dict.dict')
dictionary = corpora.Dictionary.load('jd_reviews_dict.dict')
# Out:
# 2017-07-16 16:25:20,814 : INFO : loading Dictionary object from jd_reviews_dict.dict
# 2017-07-16 16:25:20,846 : INFO : loaded jd_reviews_dict.dict

# %%
corpus = [dictionary.doc2bow(text) for text in new_reviews]
# corpora.MmCorpus.serialize('jd_reviews_mm.mm', corpus)
# corpus = corpora.MmCorpus('jd_reviews_mm.mm')

# %%
from gensim.corpora import Dictionary
from gensim.models.lsimodel import LsiModel
from gensim.models.ldamodel import LdaModel
from gensim.models.tfidfmodel import TfidfModel

# %%
lda = LdaModel(corpus=corpus, id2word=dictionary, num_topics=5, update_every=1, chunksize=10000, passes=1)
lda.print_topics(5)
# Out:
# 2017-07-14 14:19:43,434 : INFO : using symmetric alpha at 0.2
# 2017-07-14 14:19:43,437 : INFO : using symmetric eta at 3.486142583231654e-05
# 2017-07-14 14:19:43,449 : INFO : using serial LDA version on this node
# 2017-07-14 14:19:44,351 : INFO : running online (single-pass) LDA training, 5 topics, 1 passes over the supplied corpus of 7797 documents, updating model once every 7797 documents, evaluating perplexity every 7797 documents, iterating 50x with a convergence threshold of 0.001000
# 2017-07-14 14:19:44,352 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2017-07-14 14:19:59,587 : INFO : -12.219 per-word bound, 4766.4 perplexity estimate based on a held-out corpus of 7797 documents with 81268 words
# 2017-07-14 14:19:59,588 : INFO : PROGRESS: pass 0, at document #7797/7797
# 2017-07-14 14:20:09,234 : INFO : topic #0 (0.200): 0.052*"好" + 0.028*" " + 0.022*"键盘" + 0.016*"不错" + 0.013*"手感" + 0.010*"非常" + 0.009*"比较" + 0.009*"方便" + 0.009*"不" + 0.008*"蓝牙"
# 2017-07-14 14:20:09,236 : INFO : topic #1 (0.200): 0.044*"不错" + 0.023*"好" + 0.022*" " + 0.018*"好好" + 0.011*"方便" + 0.011*"键盘" + 0.009*"切换" + 0.008*"手感" + 0.006*"小巧" + 0.006*"蓝牙"
# 2017-07-14 14:20:09,238 : INFO : topic #2 (0.200): 0.021*"不错" + 0.012*"东西" + 0.010*"感觉" + 0.010*"键盘" + 0.008*"好" + 0.008*"不" + 0.007*"在" + 0.007*"鼠标" + 0.006*"有" + 0.006*"可以"
# 2017-07-14 14:20:09,241 : INFO : topic #3 (0.200): 0.039*"不错" + 0.029*" " + 0.025*"好" + 0.021*"手感" + 0.015*"非常" + 0.013*"键盘" + 0.012*"蓝牙" + 0.010*"买" + 0.009*"连接" + 0.008*"设备"
# 2017-07-14 14:20:09,244 : INFO : topic #4 (0.200): 0.022*"好" + 0.014*"键盘" + 0.014*"可以" + 0.013*"方便" + 0.011*"手感" + 0.010*"不错" + 0.010*" " + 0.008*"罗技" + 0.007*"买" + 0.007*"连接"
# 2017-07-14 14:20:09,248 : INFO : topic diff=3.940099, rho=1.000000
# 2017-07-14 14:20:09,253 : INFO : topic #0 (0.200): 0.052*"好" + 0.028*" " + 0.022*"键盘" + 0.016*"不错" + 0.013*"手感" + 0.010*"非常" + 0.009*"比较" + 0.009*"方便" + 0.009*"不" + 0.008*"蓝牙"
# 2017-07-14 14:20:09,255 : INFO : topic #1 (0.200): 0.044*"不错" + 0.023*"好" + 0.022*" " + 0.018*"好好" + 0.011*"方便" + 0.011*"键盘" + 0.009*"切换" + 0.008*"手感" + 0.006*"小巧" + 0.006*"蓝牙"
# 2017-07-14 14:20:09,258 : INFO : topic #2 (0.200): 0.021*"不错" + 0.012*"东西" + 0.010*"感觉" + 0.010*"键盘" + 0.008*"好" + 0.008*"不" + 0.007*"在" + 0.007*"鼠标" + 0.006*"有" + 0.006*"可以"
# 2017-07-14 14:20:09,261 : INFO : topic #3 (0.200): 0.039*"不错" + 0.029*" " + 0.025*"好" + 0.021*"手感" + 0.015*"非常" + 0.013*"键盘" + 0.012*"蓝牙" + 0.010*"买" + 0.009*"连接" + 0.008*"设备"
# 2017-07-14 14:20:09,266 : INFO : topic #4 (0.200): 0.022*"好" + 0.014*"键盘" + 0.014*"可以" + 0.013*"方便" + 0.011*"手感" + 0.010*"不错" + 0.010*" " + 0.008*"罗技" + 0.007*"买" + 0.007*"连接"
# [(0,
#   '0.052*"好" + 0.028*" " + 0.022*"键盘" + 0.016*"不错" + 0.013*"手感" + 0.010*"非常" + 0.009*"比较" + 0.009*"方便" + 0.009*"不" + 0.008*"蓝牙"'),
#  (1,
#   '0.044*"不错" + 0.023*"好" + 0.022*" " + 0.018*"好好" + 0.011*"方便" + 0.011*"键盘" + 0.009*"切换" + 0.008*"手感" + 0.006*"小巧" + 0.006*"蓝牙"'),
#  (2,
#   '0.021*"不错" + 0.012*"东西" + 0.010*"感觉" + 0.010*"键盘" + 0.008*"好" + 0.008*"不" + 0.007*"在" + 0.007*"鼠标" + 0.006*"有" + 0.006*"可以"'),
#  (3,
#   '0.039*"不错" + 0.029*" " + 0.025*"好" + 0.021*"手感" + 0.015*"非常" + 0.013*"键盘" + 0.012*"蓝牙" + 0.010*"买" + 0.009*"连接" + 0.008*"设备"'),
#  (4,
#   '0.022*"好" + 0.014*"键盘" + 0.014*"可以" + 0.013*"方便" + 0.011*"手感" + 0.010*"不错" + 0.010*" " + 0.008*"罗技" + 0.007*"买" + 0.007*"连接"')]

# %%
from gensim import corpora, models, similarities
tfidf = models.TfidfModel(corpus)
# Out:
# 2017-07-14 14:23:13,577 : INFO : collecting document frequencies
# 2017-07-14 14:23:13,580 : INFO : PROGRESS: processing document #0
# 2017-07-14 14:23:13,626 : INFO : calculating IDF weights for 7797 documents and 17739 features (73170 matrix non-zeros)

# %%
corpus_tfidf = tfidf[corpus]

# %%
lsi = models.LsiModel(corpus_tfidf, id2word=dictionary, num_topics=5)
# Out:
# 2017-07-14 14:23:24,867 : INFO : using serial LSI version on this node
# 2017-07-14 14:23:24,871 : INFO : updating model with new documents
# 2017-07-14 14:23:25,136 : INFO : preparing a new chunk of documents
# 2017-07-14 14:23:25,187 : INFO : using 100 extra samples and 2 power iterations
# 2017-07-14 14:23:25,189 : INFO : 1st phase: constructing (28685, 105) action matrix
# 2017-07-14 14:23:25,253 : INFO : orthonormalizing (28685, 105) action matrix
# 2017-07-14 14:23:25,991 : INFO : 2nd phase: running dense svd on (105, 7797) matrix
# 2017-07-14 14:23:26,128 : INFO : computing the final decomposition
# 2017-07-14 14:23:26,130 : INFO : keeping 5 factors (discarding 70.363% of energy spectrum)
# 2017-07-14 14:23:26,144 : INFO : processed documents up to #7797
#   '0.871*"可以" + 0.383*" " + -0.116*"不错" + 0.075*"手感" + 0.074*"东西" + 0.072*"好用" + 0.069*"鼠标" + 0.063*"非常" + -0.053*"好" + 0.050*"质量"'),
#  (3,
#   '0.796*" " + -0.473*"可以" + 0.166*"好用" + 0.128*"非常" + 0.079*"鼠标" + -0.079*"不错" + 0.077*"东西" + 0.071*"喜欢" + 0.070*"手感" + 0.066*"罗技"'),
#  (4,
#   '0.884*"好用" + -0.306*" " + 0.297*"非常" + 0.058*"鼠标" + 0.049*"满意" + 0.048*"方便" + 0.045*"小巧" + 0.045*"手感" + 0.041*"罗技" + 0.040*"喜欢"')]

# %%
print (new_reviews)
# Out:
# [['到货', '快', '键盘', '大小', '适中', '份量', '适中', '链接', '容易', '手感', '好', '14', '寸', '笔电', '尺寸', '和', '手感', '手感', '甚至', '更好', '对比', 'ThinkPad', '和', '女朋友', '华硕', '超极本', '用来', '配', 'Mac', ' ', 'mini', ' ', '看中', '其', '匹配', 'Mac', ' ', '按键', '设置'], ['好', '比', '其它', '品牌', '真的', '好多', '连接', '信号', '好', '输入', '连贯', '不卡'], ['不错', '罗技', '产品', '值得', '信赖'], ['轻便', '质感', '好', '携带方便'], ['按键', '感觉', '喜欢', '造型', '不错'], ['买来', '配', 'MAC', ' ', 'AIR', '感觉', '比', 'air', '自带', '键盘', '稍', '小', '确切的说', '键', '距', '稍微', '小', '一点', '长篇', '打字', '应该', '会', '有点累', '需要', '适应', '一下', '3', '切换', '功能', '挺强', 'MAC', ' ', 'air', '/', 'IPHONE6', '/', 'IPAD', ' ', 'mini', ' ', '这个', '3', '个', '适配', '没', '问题', '没试', 'windows', '估计', '应该', '没', '问题', '整套', '很棒', '要是', '能', '再', '大', '一点点', '完美'], ['原来', '考虑', '到', '圆形', '按键', '会', '不会', '有', '问题', '事实证明', '没有', '现在', '把', '它', '当', '生产工具'], ['好', '键盘', ' ', '特别', '好用'], ['上午', '下单', '下午', '送到', '字', '快', '考虑', '安卓', 'PC', 'Mac', '选择', '这', '款'], ['不错', '手感', '不错'], ['非常', '有', '质感', '有', '分量', '又', '有', '手感', '蓝牙', '非常', '好用', '把', '无线', '键盘', '淘汰'], ['超级', '赞', '现在', '这个', '评价', '键盘', '打', '非常', '方便', '连接', '简单', '快速', '切换', '十分', '顺畅', '还有', '个', '小', '手机', '架子', '真是', '解决', '电脑', '手机', '切换', '大', '问题', '灰色', '质感', '好', '高档', '圆圆的', '键盘', '又', '萌萌', '嗒', '还有', '个', '很大', '优点', '轻', '随身携带', '算', '方便'], ['非常', '好用', '有', '质感', '喜欢'], ['配合', '平板', '电脑', 'thinkpad8', '好', '刚', '开始', '暂时', '很大', '而且', '有', '粘键', '后来', '更改', '网卡', '高级', '中', 'Bluetooth', ' ', 'collaboration', '为', 'disable', '后', '可以', '完美', '使用'], ['做工', '不错', '手感', '也好', '有', '分量'], ['快递', '和', '东西', '好', '送', '这个', '东西', '没什么', '用处'], ['非常', '有', '手感', ' ', '不错', ' ', '舒服'], ['好', '东西', '下次', '再', '买', '更', '多'], ['非常', '好', '产品', '喜欢'], ['不错', '略爽'], ['好', '打字', '手感', '好', '设备', '切换', '速度', '快'], ['